# %% [markdown]
# ## Results
# All the different models are run for both 'GT Compressor decay state coefficient' and 'GT Compressor decay state coefficient'
# seprately and thier mean absolute error and root mean squared error are recoreded for every model and displayed in two seprate data frames namely Summary_C and Summary_T.

# %%
cd C:\Users\DK\OneDrive\Desktop\Coursera\Projects\Propulsion
# Out:
# C:\Users\DK\OneDrive\Desktop\Coursera\Projects\Propulsion

# %%
from propulsion_function import *
import pandas as pd

# Input variables
work_dir = 'C:/Users/DK/OneDrive/Desktop/Coursera/Projects/Propulsion'  # present working directory
df = pd.read_csv(work_dir + '/propulsion.csv')                          # loading data 
epoch = 30
batch = 128

#===========================================================================================================================

# NOTE: There are two columns to predict namely GT Compressor decay state coefficient, GT Turbine decay state coefficient,
#       in the sample example beow the models are predicting GT Compressor decay state coefficient, for predicting the 
#       just un-comment the second exmample which is commneted.


X,y=data(df, 'GT Compressor decay state coefficient.') 

feature_selector(X, y)
X = imp_data(X)
X_train, X_test, y_train, y_test = data_split(X, y)

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# C:\Users\DK\anaconda3\envs\python35\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# The correlation of features with target:
#
# [0.00779509 0.02237787 0.08089405 0.06394914 0.17361022 0.01603403
#  0.03459641 0.04680896 0.         0.19252413 0.09429299 0.
#  0.02578897 0.17442519 0.02507988 0.02140607 0.020417  ]

# %% [markdown]
# ### Model run for GT Compressor decay state coefficient

# %% [markdown]
# #### 1.Linear Model

# %%
predictions_C_1, error_C_1, coefficients_C_1, intercept_C_1,  mae_C_1, rmse_C_1, model_C_1 = create_model(X_train, X_test, y_train, y_test, 'Linear')
# Out:
# Training a Linear model...
# Model trained!
# Making predictions and calculating errors...
#
#
# The mean absolute error of model is:0.003214756518234767
# The root mean squared error of model is:0.00447898186516776

# %% [markdown]
# #### 2 Ridge Model

# %%
predictions_C_2, error_C_2, coefficients_C_2, intercept_C_2, mae_C_2, rmse_C_2, model_C_2 = create_model(X_train, X_test, y_train, y_test, 'Ridge')
# Out:
# Training a Ridge model...
# Model trained!
# Making predictions and calculating errors...
#
#
# The mean absolute error of model is:0.003222865626390521
# The root mean squared error of model is:0.004479674004062949

# %% [markdown]
# #### 3.Lasso

# %%
predictions_C_3, error_C_3, coefficients_C_3, intercept_C_3, mae_C_3, rmse_C_3, model_C_3 = create_model(X_train, X_test, y_train, y_test, 'Lasso')
# Out:
# Training a Lasso model...
# Model trained!
# Making predictions and calculating errors...
#
#
# The mean absolute error of model is:0.010943736306031985
# The root mean squared error of model is:0.012762310254733643

# %% [markdown]
# #### 4.Neural Network

# %%
predictions_C_4, error_C_4, weight_C_4, mae_C_4, rmse_C_4, model_C_4 = neural_network(X_train, X_test, y_train, y_test, epoch, batch)
# Out:
# Training Neural Network...
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/30
# 7000/7000 [==============================] - 2s 293us/step - loss: 1.0147 - val_loss: 0.6916
# Epoch 2/30
# 7000/7000 [==============================] - 0s 42us/step - loss: 0.3476 - val_loss: 0.0503
# Epoch 3/30
# 7000/7000 [==============================] - 0s 42us/step - loss: 0.0127 - val_loss: 0.0020
# Epoch 4/30
# 7000/7000 [==============================] - 0s 42us/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 5/30
# 7000/7000 [==============================] - 0s 45us/step - loss: 8.0758e-04 - val_loss: 6.7632e-04
# Epoch 6/30
# 7000/7000 [==============================] - 0s 42us/step - loss: 5.8194e-04 - val_loss: 5.2011e-04
# Epoch 7/30
# 7000/7000 [==============================] - 0s 40us/step - loss: 4.3120e-04 - val_loss: 4.0424e-04
# Epoch 8/30
# 7000/7000 [==============================] - 0s 43us/step - loss: 3.4507e-04 - val_loss: 3.1237e-04
# Epoch 9/30
# ...

# %% [markdown]
# .

# %% [markdown]
# ========================================================================================================================

# %% [markdown]
# .

# %% [markdown]
# ### Model run for GT Turbine decay state coefficient

# %%
X,y=data(df, 'GT Turbine decay state coefficient.')

feature_selector(X, y)
X = imp_data(X)
X_train, X_test, y_train, y_test = data_split(X, y)

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# C:\Users\DK\anaconda3\envs\python35\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# The correlation of features with target:
#
# [0.00652077 0.01902985 0.07327432 0.07633134 0.11731088 0.02121776
#  0.01604971 0.06184724 0.         0.02627906 0.02355068 0.
#  0.323975   0.0301566  0.08088461 0.08257043 0.04100175]

# %% [markdown]
# #### 1.Linear

# %%
predictions_T_1, error_T_1, coefficients_T_1, intercept_T_1,  mae_T_1, rmse_T_1, model_T_1 = create_model(X_train, X_test, y_train, y_test, 'Linear')
# Out:
# Training a Linear model...
# Model trained!
# Making predictions and calculating errors...
#
#
# The mean absolute error of model is:0.0011609848366803711
# The root mean squared error of model is:0.0017271724921677357

# %% [markdown]
# #### 2.Ridge

# %%
predictions_T_2, error_T_2, coefficients_T_2, intercept_T_2, mae_T_2, rmse_T_2, model_T_2 = create_model(X_train, X_test, y_train, y_test, 'Ridge')
# Out:
# Training a Ridge model...
# Model trained!
# Making predictions and calculating errors...
#
#
# The mean absolute error of model is:0.0011617535422819643
# The root mean squared error of model is:0.0017267375312852694

# %% [markdown]
# #### 3.Lasso

# %%
predictions_T_3, error_T_3, coefficients_T_3, intercept_T_3, mae_T_3, rmse_T_3, model_T_3 = create_model(X_train, X_test, y_train, y_test, 'Lasso')
# Out:
# Training a Lasso model...
# Model trained!
# Making predictions and calculating errors...
#
#
# The mean absolute error of model is:0.006479104666666676
# The root mean squared error of model is:0.007466206466472793

# %% [markdown]
# #### 4.Neural Network

# %%
predictions_T_4, error_T_4, weight_T_4, mae_T_4, rmse_T_4, model_T_4 = neural_network(X_train, X_test, y_train, y_test, epoch, batch)
# Out:
# Training Neural Network...
# Train on 7000 samples, validate on 3000 samples
# Epoch 1/30
# 7000/7000 [==============================] - 2s 309us/step - loss: 0.1865 - val_loss: 0.0149
# Epoch 2/30
# 7000/7000 [==============================] - 0s 47us/step - loss: 0.0059 - val_loss: 0.0023
# Epoch 3/30
# 7000/7000 [==============================] - 0s 51us/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 4/30
# 7000/7000 [==============================] - 0s 46us/step - loss: 8.2497e-04 - val_loss: 6.3913e-04
# Epoch 5/30
# 7000/7000 [==============================] - 0s 48us/step - loss: 4.9921e-04 - val_loss: 4.1008e-04
# Epoch 6/30
# 7000/7000 [==============================] - 0s 48us/step - loss: 3.3652e-04 - val_loss: 2.9702e-04
# Epoch 7/30
# 7000/7000 [==============================] - 0s 45us/step - loss: 2.5554e-04 - val_loss: 2.3080e-04
# Epoch 8/30
# 7000/7000 [==============================] - 0s 45us/step - loss: 2.1082e-04 - val_loss: 1.9479e-04
# Epoch 9/30
# ...

# %% [markdown]
# .

# %% [markdown]
# ========================================================================================================================

# %% [markdown]
# .

# %% [markdown]
# ## Results

# %%
Summary_C =  pd.DataFrame({'Model':['Linear', 'Ridge', 'Lasso', 'NN'],
                        'MAE': [mae_C_1, mae_C_2, mae_C_3, mae_C_4],
                        'RMSE': [rmse_C_1, rmse_C_2, rmse_C_3, rmse_C_4]})
Summary_C
# Out:
#         MAE   Model      RMSE
# 0  0.003215  Linear  0.004479
# 1  0.003223   Ridge  0.004480
# 2  0.010944   Lasso  0.012762
# 3  0.006344      NN  0.007578

# %%
Summary_T =  pd.DataFrame({'Model':['Linear', 'Ridge', 'Lasso', 'NN'],
                        'MAE': [mae_T_1, mae_T_2, mae_T_3, mae_T_4],
                        'RMSE': [rmse_T_1, rmse_T_2, rmse_T_3, rmse_T_4]})
Summary_T
# Out:
#         MAE   Model      RMSE
# 0  0.001161  Linear  0.001727
# 1  0.001162   Ridge  0.001727
# 2  0.006479   Lasso  0.007466
# 3  0.007012      NN  0.008488
